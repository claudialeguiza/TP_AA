# %% [markdown]
# # Trabajo práctico
#
# # **Aprendizaje Automático I**
#
# ### Tema: Predicción de lluvia en Australia.
#
# ## Integrantes:
#
#
# *   Kidonakis, Sol
# *   Leguiza, Claudia E

# %% [markdown]
# # Dataset
#
# El dataset **weatherAUS.csv** contiene infomacion del clima de diferentes ciudades de Australia recopilada durante el periodo 2008 - 2017.
#
# Contiene un total de 145412 observaciones y las siguientes columnas:
#
#
#
# 0.   Date:   fecha de la observacion
# 1.   Location
# 2.   MinTemp
# 3.   MaxTemp
# 4.   Rainfall
# 5.   Evapooration
# 6.   Sunshine
# 7.   WindGustDir
# 8.   WindGustSpeed
# 9.   WindDir9am:
# 10.  WindDir3pm:
# 11.  WindSpeed9am:
# 12.  WindSpeed3pm:
# 13.  Humidity9am:
# 14.  Humidity3pm:
# 15.  Pressure9am:
# 16.  Pressure3pm:
# 17.  Cloud9am:
# 18.  Cloud3pm:
# 19.  Temp9am:
# 20.  Temp3pm:
# 21.  RainToday:
# 22.  RainTomorrow:
# 23.  Rainfall Tomorrow

# %% [markdown]
# # Objetivo:
#
#   Predecir las target **RainTomorrow** y **RainfallTomorrow** en las ciudades de Adelaide, Canberra, Cobar, Dartmoor, Melbourne, MelbourneAirport, MountGambier, Sydney y SydneyAirport

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.set()
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import RobustScaler
from sklearn.linear_model import ElasticNetCV
from sklearn.linear_model import LassoCV
from sklearn.linear_model import RidgeCV

#from sklearn.metrics import roc_curve, auc
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, mean_absolute_percentage_error
#from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay

import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# # Carga de datos

# %%
datos = pd.read_csv('/content/weatherAUS.csv', delimiter = ",")

# %%
datos.head()
# Out:
#    Unnamed: 0        Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0           0  2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1           1  2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2           2  2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3           3  2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4           4  2008-12-05   Albury     17.5     32.3       1.0          NaN
#
#    Sunshine WindGustDir  WindGustSpeed  ... Humidity3pm Pressure9am  \
# 0       NaN           W           44.0  ...        22.0      1007.7
# 1       NaN         WNW           44.0  ...        25.0      1010.6
# 2       NaN         WSW           46.0  ...        30.0      1007.6
# 3       NaN          NE           24.0  ...        16.0      1017.6
# 4       NaN           W           41.0  ...        33.0      1010.8
#
#    Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RainTomorrow  \
# 0       1007.1       8.0       NaN     16.9     21.8         No            No
# 1       1007.8       NaN       NaN     17.2     24.3         No            No
# 2       1008.7       NaN       2.0     21.0     23.2         No            No
# 3       1012.8       NaN       NaN     18.1     26.5         No            No
# 4       1006.0       7.0       8.0     17.8     29.7         No            No
#
#    RainfallTomorrow
# 0               0.0
# 1               0.0
# 2               0.0
# 3               1.0
# 4               0.2
#
# [5 rows x 25 columns]

# %%
datos['Location'].unique()
# Out:
# array(['Albury', 'BadgerysCreek', 'Cobar', 'CoffsHarbour', 'Moree',
#        'Newcastle', 'NorahHead', 'NorfolkIsland', 'Penrith', 'Richmond',
#        'Sydney', 'SydneyAirport', 'WaggaWagga', 'Williamtown',
#        'Wollongong', 'Canberra', 'Tuggeranong', 'MountGinini', 'Ballarat',
#        'Bendigo', 'Sale', 'MelbourneAirport', 'Melbourne', 'Mildura',
#        'Nhil', 'Portland', 'Watsonia', 'Dartmoor', 'Brisbane', 'Cairns',
#        'GoldCoast', 'Townsville', 'Adelaide', 'MountGambier', 'Nuriootpa',
#        'Woomera', 'Albany', 'Witchcliffe', 'PearceRAAF', 'PerthAirport',
#        'Perth', 'SalmonGums', 'Walpole', 'Hobart', 'Launceston',
#        'AliceSprings', 'Darwin', 'Katherine', 'Uluru'], dtype=object)

# %%
datos['Location'].count()
# Out:
# 145412

# %% [markdown]
# Buscamos los registros correspondientes a las localidades en estudio.
# Creamos un dataset nuevo con ellas.
#
# A fin de completar los datos nulos las tomaremos como una sola region.

# %%
datos['Location'].isin(( 'Sydney','SydneyAirport','Melbourne', 'MelbourneAirport','Canberra',\
                       'Adelaide', 'MountGambier','Cobar', 'Dartmoor' )).value_counts()
# Out:
# Location
# False    117179
# True      28233
# Name: count, dtype: int64

# %%
data = datos[datos.Location\
                      .isin(( 'Sydney','SydneyAirport','Melbourne', 'MelbourneAirport',\
                             'Canberra','Adelaide', 'MountGambier','Cobar', 'Dartmoor' ))]

# %%
data
# Out:
#         Unnamed: 0        Date      Location  MinTemp  MaxTemp  Rainfall  \
# 6047          6049  2009-01-01         Cobar     17.9     35.2       0.0
# 6048          6050  2009-01-02         Cobar     18.4     28.9       0.0
# 6049          6051  2009-01-03         Cobar     15.5     34.1       0.0
# 6050          6052  2009-01-04         Cobar     19.4     37.6       0.0
# 6051          6053  2009-01-05         Cobar     21.9     38.4       0.0
# ...            ...         ...           ...      ...      ...       ...
# 102515      102547  2017-06-20  MountGambier      6.2     16.3       0.0
# 102516      102548  2017-06-21  MountGambier      8.7     13.2       2.0
# 102517      102549  2017-06-22  MountGambier      7.0     15.7       0.0
# 102518      102550  2017-06-23  MountGambier      5.4     16.2       0.0
# 102519      102551  2017-06-24  MountGambier      4.8     12.3       2.2
#
#         Evaporation  Sunshine WindGustDir  WindGustSpeed  ... Humidity3pm  \
# 6047           12.0      12.3         SSW           48.0  ...        13.0
# 6048           14.8      13.0           S           37.0  ...         8.0
# 6049           12.6      13.3          SE           30.0  ...         7.0
# 6050           10.8      10.6         NNE           46.0  ...        22.0
# 6051           11.4      12.2         WNW           31.0  ...        22.0
# ...             ...       ...         ...            ...  ...         ...
# 102515          NaN       NaN           N           41.0  ...        70.0
# 102516          NaN       NaN           S           20.0  ...        82.0
# 102517          NaN       NaN           N           31.0  ...        67.0
# 102518          NaN       NaN           N           37.0  ...        70.0
# 102519          NaN       NaN           W           28.0  ...        70.0
#
#        Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 6047        1006.3       1004.4       2.0       5.0     26.6     33.4
# 6048        1012.9       1012.1       1.0       1.0     20.3     27.0
# 6049           NaN       1011.6       NaN       1.0      NaN     32.7
# 6050        1012.3       1009.2       1.0       6.0     28.7     34.9
# 6051        1012.7       1009.1       1.0       5.0     29.1     35.6
# ...            ...          ...       ...       ...      ...      ...
# 102515      1026.3       1024.1       NaN       NaN      8.7     15.5
# 102516      1029.2       1028.3       NaN       8.0     11.1     12.0
# 102517      1027.0       1022.4       8.0       NaN     10.0     14.9
# 102518      1017.0       1014.4       8.0       4.0      6.4     14.9
# 102519      1020.0       1018.0       5.0       8.0      8.2     11.5
#
#         RainToday  RainTomorrow  RainfallTomorrow
# 6047           No            No               0.0
# 6048           No            No               0.0
# 6049           No            No               0.0
# 6050           No            No               0.0
# 6051           No            No               0.0
# ...           ...           ...               ...
# 102515         No           Yes               2.0
# 102516        Yes            No               0.0
# 102517         No            No               0.0
# 102518         No           Yes               2.2
# 102519        Yes            No               0.6
#
# [28233 rows x 25 columns]

# %% [markdown]
# # Particion de conjuntos de entrenamiento, validacion y prueba

# %% [markdown]
# Verificamos si el dataset esta balanceado antes de realizar la particion

# %%
valores = data['Location'].value_counts()

# %%
plt.figure(figsize=(10, 5))
plt.xticks(rotation=75, fontsize=12)
plt.yticks(fontsize=12)
plt.ylabel('Cantidad', fontsize=14)
plt.title('Datos del tiempo registrados entre 2008 - 2017',
          fontsize=16)
plt.bar(valores.index, valores)
plt.show()

# %% [markdown]
# El dataset esta desbalanceado por lo que aplicamos un truncamiento  utilizando como referencia la fecha de aparicion en el dataset de las ciudades con menores observaciones.

# %%
df= data.copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 28233 entries, 6047 to 102519
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        28233 non-null  int64
#  1   Date              28233 non-null  object
#  2   Location          28233 non-null  object
#  3   MinTemp           27663 non-null  float64
#  4   MaxTemp           27675 non-null  float64
#  5   Rainfall          27247 non-null  float64
#  6   Evaporation       23880 non-null  float64
#  7   Sunshine          21520 non-null  float64
#  8   WindGustDir       26588 non-null  object
#  9   WindGustSpeed     26591 non-null  float64
#  10  WindDir9am        26585 non-null  object
#  11  WindDir3pm        27796 non-null  object
#  12  WindSpeed9am      27875 non-null  float64
#  13  WindSpeed3pm      27893 non-null  float64
#  14  Humidity9am       27293 non-null  float64
#  15  Humidity3pm       27343 non-null  float64
#  16  Pressure9am       27394 non-null  float64
#  17  Pressure3pm       27404 non-null  float64
#  18  Cloud9am          18866 non-null  float64
#  19  Cloud3pm          18683 non-null  float64
#  20  Temp9am           27648 non-null  float64
#  21  Temp3pm           27657 non-null  float64
#  22  RainToday         27247 non-null  object
#  23  RainTomorrow      27248 non-null  object
#  24  RainfallTomorrow  27248 non-null  float64
# dtypes: float64(17), int64(1), object(7)
# memory usage: 5.6+ MB

# %%
df = df.sort_values(["Date"])
fecha_especifica = '2009-01-01'
df_filtrado = df[df['Date'] >= fecha_especifica]

df_filtrado.reset_index(drop = True, inplace = True)#Resetea el indice y no  crea uno  nuevo
df_filtrado
# Out:
#        Unnamed: 0        Date       Location  MinTemp  MaxTemp  Rainfall  \
# 0           99544  2009-01-01   MountGambier     12.6     17.0       0.8
# 1           96504  2009-01-01       Adelaide     16.9     22.9       0.0
# 2           30511  2009-01-01         Sydney     18.4     34.7       0.0
# 3           80998  2009-01-01       Dartmoor      NaN      NaN       NaN
# 4           33520  2009-01-01  SydneyAirport     17.7     35.1       0.0
# ...           ...         ...            ...      ...      ...       ...
# 27067       49021  2017-06-24       Canberra      0.1     14.4       0.0
# 27068       84005  2017-06-24       Dartmoor      6.2     11.8       3.0
# 27069        9056  2017-06-24          Cobar      8.3     16.2       0.0
# 27070       99511  2017-06-24       Adelaide      5.0     17.3       0.0
# 27071      102551  2017-06-24   MountGambier      4.8     12.3       2.2
#
#        Evaporation  Sunshine WindGustDir  WindGustSpeed  ... Humidity3pm  \
# 0              4.8       6.5          SW           56.0  ...        43.0
# 1              NaN      10.9          SW           50.0  ...        40.0
# 2              9.8      12.9         NaN            NaN  ...        22.0
# 3              4.8       6.5         NaN            NaN  ...         NaN
# 4              9.8      12.9           S           72.0  ...        13.0
# ...            ...       ...         ...            ...  ...         ...
# 27067          NaN       NaN          NW           48.0  ...        45.0
# 27068          NaN       NaN           W           20.0  ...        70.0
# 27069          NaN       NaN         WSW           20.0  ...        49.0
# 27070          NaN       NaN           W           17.0  ...        54.0
# 27071          NaN       NaN           W           28.0  ...        70.0
#
#       Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 0          1008.3       1011.6       7.0       5.0     14.3     16.6
# 1          1011.3       1012.4       NaN       NaN     18.1     22.5
# 2          1005.5       1000.7       4.0       6.0     22.0     34.3
# 3             NaN          NaN       NaN       NaN      NaN      NaN
# 4          1005.3       1000.2       6.0       6.0     22.9     34.0
# ...           ...          ...       ...       ...      ...      ...
# 27067      1017.5       1016.2       NaN       NaN      9.1     13.0
# 27068      1019.8       1017.8       NaN       NaN      6.9     10.9
# 27069      1020.2       1018.5       NaN       7.0     14.2     14.5
# 27070      1020.7       1018.5       NaN       NaN      9.6     16.7
# 27071      1020.0       1018.0       5.0       8.0      8.2     11.5
#
#        RainToday  RainTomorrow  RainfallTomorrow
# 0             No            No               0.0
# 1             No            No               0.0
# 2             No            No               0.0
# 3            NaN           NaN               NaN
# 4             No            No               0.0
# ...          ...           ...               ...
# 27067         No            No               0.0
# 27068        Yes            No               0.2
# 27069         No            No               0.0
# 27070         No            No               0.0
# 27071        Yes            No               0.6
#
# [27072 rows x 25 columns]

# %%
df_filtrado['Location'].value_counts()
# Out:
# Location
# MountGambier        3008
# Adelaide            3008
# Sydney              3008
# Dartmoor            3008
# SydneyAirport       3008
# Cobar               3008
# Melbourne           3008
# Canberra            3008
# MelbourneAirport    3008
# Name: count, dtype: int64

# %%
df_filtrado = df_filtrado.drop('Unnamed: 0', axis =1)

# %% [markdown]
# Vamos a destinar el 80% de los datos a training y 20% a test

# %%
df_train  = df_filtrado.iloc[:21657]
df_train
# Out:
#              Date       Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0      2009-01-01   MountGambier     12.6     17.0       0.8          4.8
# 1      2009-01-01       Adelaide     16.9     22.9       0.0          NaN
# 2      2009-01-01         Sydney     18.4     34.7       0.0          9.8
# 3      2009-01-01       Dartmoor      NaN      NaN       NaN          4.8
# 4      2009-01-01  SydneyAirport     17.7     35.1       0.0          9.8
# ...           ...            ...      ...      ...       ...          ...
# 21652  2015-10-31       Adelaide     15.0     28.0       0.0          NaN
# 21653  2015-10-31       Dartmoor     12.8     27.7       3.8          3.6
# 21654  2015-11-01       Canberra      8.9     25.3       2.2          NaN
# 21655  2015-11-01  SydneyAirport     17.5     28.7       0.0          7.8
# 21656  2015-11-01       Dartmoor      9.9     17.8       0.0          6.6
#
#        Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  \
# 0           6.5          SW           56.0         SW  ...        43.0
# 1          10.9          SW           50.0         SW  ...        40.0
# 2          12.9         NaN            NaN          W  ...        22.0
# 3           6.5         NaN            NaN        NaN  ...         NaN
# 4          12.9           S           72.0         NW  ...        13.0
# ...         ...         ...            ...        ...  ...         ...
# 21652       NaN          SW           22.0        NNW  ...        22.0
# 21653      12.0         ENE           43.0        ENE  ...        34.0
# 21654       NaN           W           57.0         NW  ...        60.0
# 21655       9.0           N           56.0        NNE  ...        54.0
# 21656       1.8           W           30.0         NW  ...        70.0
#
#        Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 0           1008.3       1011.6       7.0       5.0     14.3     16.6
# 1           1011.3       1012.4       NaN       NaN     18.1     22.5
# 2           1005.5       1000.7       4.0       6.0     22.0     34.3
# 3              NaN          NaN       NaN       NaN      NaN      NaN
# 4           1005.3       1000.2       6.0       6.0     22.9     34.0
# ...            ...          ...       ...       ...      ...      ...
# 21652       1013.7       1010.7       NaN       NaN     18.3     26.7
# 21653       1011.4       1008.5       NaN       NaN     19.5     26.8
# 21654       1015.7       1010.7       NaN       8.0     18.1     20.8
# 21655       1015.0       1010.1       1.0       3.0     22.4     26.7
# 21656       1010.1       1008.8       NaN       NaN     14.5     16.9
#
#        RainToday  RainTomorrow  RainfallTomorrow
# 0             No            No               0.0
# 1             No            No               0.0
# 2             No            No               0.0
# 3            NaN           NaN               NaN
# 4             No            No               0.0
# ...          ...           ...               ...
# 21652         No            No               0.4
# 21653        Yes            No               0.0
# 21654        Yes           Yes              19.4
# 21655         No           Yes               9.8
# 21656         No            No               1.0
#
# [21657 rows x 24 columns]

# %%
df_test = df_filtrado.iloc[21657:]
df_test
# Out:
#              Date          Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 21657  2015-11-01          Adelaide     15.5     25.2       0.4          NaN
# 21658  2015-11-01  MelbourneAirport     15.0     27.0       4.8          7.0
# 21659  2015-11-01             Cobar     16.7     30.2       2.4          7.2
# 21660  2015-11-01      MountGambier     12.0     18.3       0.0          6.6
# 21661  2015-11-01            Sydney     17.5     26.8       0.0          7.8
# ...           ...               ...      ...      ...       ...          ...
# 27067  2017-06-24          Canberra      0.1     14.4       0.0          NaN
# 27068  2017-06-24          Dartmoor      6.2     11.8       3.0          NaN
# 27069  2017-06-24             Cobar      8.3     16.2       0.0          NaN
# 27070  2017-06-24          Adelaide      5.0     17.3       0.0          NaN
# 27071  2017-06-24      MountGambier      4.8     12.3       2.2          NaN
#
#        Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  \
# 21657       NaN         WSW           28.0        NaN  ...        21.0
# 21658       5.2           N           72.0          N  ...        59.0
# 21659       NaN           W           65.0         NE  ...        45.0
# 21660       1.8         WNW           37.0        WNW  ...        77.0
# 21661       9.0          NE           44.0          E  ...        59.0
# ...         ...         ...            ...        ...  ...         ...
# 27067       NaN          NW           48.0          N  ...        45.0
# 27068       NaN           W           20.0         NW  ...        70.0
# 27069       NaN         WSW           20.0          W  ...        49.0
# 27070       NaN           W           17.0        NaN  ...        54.0
# 27071       NaN           W           28.0        NNW  ...        70.0
#
#        Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 21657       1010.3       1009.7       NaN       NaN     18.5     24.1
# 21658       1008.3       1006.7       4.0       7.0     21.2     21.0
# 21659       1012.9       1008.3       6.0       6.0     21.6     28.2
# 21660       1010.7       1009.0       8.0       7.0     14.9     15.3
# 21661       1015.2       1010.6       1.0       3.0     21.9     25.4
# ...            ...          ...       ...       ...      ...      ...
# 27067       1017.5       1016.2       NaN       NaN      9.1     13.0
# 27068       1019.8       1017.8       NaN       NaN      6.9     10.9
# 27069       1020.2       1018.5       NaN       7.0     14.2     14.5
# 27070       1020.7       1018.5       NaN       NaN      9.6     16.7
# 27071       1020.0       1018.0       5.0       8.0      8.2     11.5
#
#        RainToday  RainTomorrow  RainfallTomorrow
# 21657         No            No               0.0
# 21658        Yes            No               0.2
# 21659        Yes           Yes               7.6
# 21660         No           Yes               2.6
# 21661         No           Yes              26.0
# ...          ...           ...               ...
# 27067         No            No               0.0
# 27068        Yes            No               0.2
# 27069         No            No               0.0
# 27070         No            No               0.0
# 27071        Yes            No               0.6
#
# [5415 rows x 24 columns]

# %% [markdown]
# ### Funciones

# %%
def preprocesamiento(data):
    data.info()
    data.isna().sum()

    # Definir columnas con valores nulos
    columnas_con_nulos = ['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
                          'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm','Humidity9am',
                          'Humidity3pm', 'Pressure9am','Pressure3pm', 'Cloud9am',
                          'Cloud3pm', 'Temp9am', 'Temp3pm', 'RainfallTomorrow']

    # Rellenar valores faltantes en 'RainToday' y 'RainTomorrow'
    data['RainToday'] = data.groupby('Date')['RainToday'].transform(lambda x: x.fillna(x.mode().iloc[0]))
    data['RainTomorrow'] = data.groupby('Date')['RainTomorrow'].transform(lambda x: x.fillna(x.mode().iloc[0]))

    # Rellenar valores faltantes en direcciones del viento
    data['WindGustDir'] = data.groupby('Date')['WindGustDir'].transform(lambda x: x.fillna(x.mode().iloc[0]) if not x.isna().all() else x)
    data['WindDir9am'] = data.groupby('Date')['WindDir9am'].transform(lambda x: x.fillna(x.mode().iloc[0]) if not x.isna().all() else x)
    data['WindDir3pm'] = data.groupby('Date')['WindDir3pm'].transform(lambda x: x.fillna(x.mode().iloc[0]) if not x.isna().all() else x)

    # Rellenar valores faltantes con la media por día para las columnas especificadas
    media_por_dia = data.groupby('Date')[columnas_con_nulos].transform('mean')
    data[columnas_con_nulos] = data[columnas_con_nulos].fillna(media_por_dia)

    data['Date'] = pd.to_datetime(data['Date'])

    return data

# %%
def asignar_estacion(fecha):
    mes = fecha.month
    if mes in [12, 1, 2]:  # Verano: Diciembre, Enero, Febrero
        return 'Summer'
    elif mes in [3, 4, 5]:  # Otoño: Marzo, Abril, Mayo
        return 'Autumn'
    elif mes in [6, 7, 8]:  # Invierno: Junio, Julio, Agosto
        return 'Winter'
    else:  # Primavera: Septiembre, Octubre, Noviembre
        return 'Spring'

# %%
def estandarizar(data):

  # Seleccionar solo las columnas numéricas para estandarizar
  data_numeric = data.select_dtypes(include=['float64', 'int64'])

  scaler = RobustScaler()
  data_standardized = scaler.fit_transform(data)

  # Crear un nuevo DataFrame con los datos estandarizados
  data_standardized = pd.DataFrame(data_standardized, columns=df_train.columns)

  return data_standardized

# %%
def codificar_variables(data):

  data1 = data.copy()

  for var in ["SW", "S", 'SSW', 'W', 'SSE', 'E', 'SE', 'NE', 'NNE', 'WSW', 'WNW',
            'NW', 'N', 'ESE', 'ENE']:
    # Crear columnas para WindGustDir
    data1[f'WindGustDir_{var}'] = 0
    data1.loc[data['WindGustDir'] == var, f'WindGustDir_{var}'] = 1

    # Crear columnas para WindGust9am
    data1[f'WindDir9am_{var}'] = 0
    data1.loc[data['WindDir9am'] == var, f'WindDir9am_{var}'] = 1

    # Crear columnas para WindGust3pm
    data1[f'WindDir3pm_{var}'] = 0
    data1.loc[data['WindDir3pm'] == var, f'WindDir3pm_{var}'] = 1

    # Generamos dummys
    # Codificar la variable 'RainToday'
  data1 = pd.get_dummies(data1, columns=['RainToday'],drop_first=True)

    # Codificar la variable 'RainTomorrow'
  data1 = pd.get_dummies(data1, columns=['RainTomorrow'],drop_first=True)

    # Codificar la variable 'season'
  data1 = pd.get_dummies(data1, columns=['season'],drop_first=True)

    # Codificar la variable 'Location'
  data1 = pd.get_dummies(data1, columns=['Location'], drop_first=True)

  return data1

# %% [markdown]
# ## Preprocesamiento

# %%
df_filtrado = preprocesamiento(df_filtrado)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27072 entries, 0 to 27071
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              27072 non-null  object
#  1   Location          27072 non-null  object
#  2   MinTemp           26503 non-null  float64
#  3   MaxTemp           26515 non-null  float64
#  4   Rainfall          26104 non-null  float64
#  5   Evaporation       22782 non-null  float64
#  6   Sunshine          20366 non-null  float64
#  7   WindGustDir       25769 non-null  object
#  8   WindGustSpeed     25771 non-null  float64
#  9   WindDir9am        25472 non-null  object
#  10  WindDir3pm        26640 non-null  object
#  11  WindSpeed9am      26725 non-null  float64
#  12  WindSpeed3pm      26735 non-null  float64
#  13  Humidity9am       26133 non-null  float64
#  14  Humidity3pm       26183 non-null  float64
#  15  Pressure9am       26235 non-null  float64
#  16  Pressure3pm       26243 non-null  float64
#  17  Cloud9am          17889 non-null  float64
#  18  Cloud3pm          17706 non-null  float64
#  19  Temp9am           26488 non-null  float64
#  20  Temp3pm           26496 non-null  float64
#  21  RainToday         26104 non-null  object
#  22  RainTomorrow      26105 non-null  object
#  23  RainfallTomorrow  26105 non-null  float64
# dtypes: float64(17), object(7)
# memory usage: 5.0+ MB

# %%
df_filtrado['season'] =  df_filtrado['Date'].apply(asignar_estacion)
df_filtrado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27072 entries, 0 to 27071
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              27072 non-null  datetime64[ns]
#  1   Location          27072 non-null  object
#  2   MinTemp           27072 non-null  float64
#  3   MaxTemp           27072 non-null  float64
#  4   Rainfall          27072 non-null  float64
#  5   Evaporation       27072 non-null  float64
#  6   Sunshine          27072 non-null  float64
#  7   WindGustDir       27072 non-null  object
#  8   WindGustSpeed     27072 non-null  float64
#  9   WindDir9am        27072 non-null  object
#  10  WindDir3pm        27072 non-null  object
#  11  WindSpeed9am      27072 non-null  float64
#  12  WindSpeed3pm      27072 non-null  float64
#  13  Humidity9am       27072 non-null  float64
#  14  Humidity3pm       27072 non-null  float64
#  15  Pressure9am       27072 non-null  float64
#  16  Pressure3pm       27072 non-null  float64
#  17  Cloud9am          27072 non-null  float64
#  18  Cloud3pm          27072 non-null  float64
#  19  Temp9am           27072 non-null  float64
#  20  Temp3pm           27072 non-null  float64
#  21  RainToday         27072 non-null  object
#  22  RainTomorrow      27072 non-null  object
#  23  RainfallTomorrow  27072 non-null  float64
#  24  season            27072 non-null  object
# dtypes: datetime64[ns](1), float64(17), object(7)
# memory usage: 5.2+ MB

# %%
df_train = preprocesamiento(df_train)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21657 entries, 0 to 21656
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              21657 non-null  object
#  1   Location          21657 non-null  object
#  2   MinTemp           21276 non-null  float64
#  3   MaxTemp           21289 non-null  float64
#  4   Rainfall          20907 non-null  float64
#  5   Evaporation       19653 non-null  float64
#  6   Sunshine          17626 non-null  float64
#  7   WindGustDir       20426 non-null  object
#  8   WindGustSpeed     20428 non-null  float64
#  9   WindDir9am        20284 non-null  object
#  10  WindDir3pm        21248 non-null  object
#  11  WindSpeed9am      21318 non-null  float64
#  12  WindSpeed3pm      21324 non-null  float64
#  13  Humidity9am       21028 non-null  float64
#  14  Humidity3pm       21072 non-null  float64
#  15  Pressure9am       21009 non-null  float64
#  16  Pressure3pm       21014 non-null  float64
#  17  Cloud9am          14573 non-null  float64
#  18  Cloud3pm          14287 non-null  float64
#  19  Temp9am           21261 non-null  float64
#  20  Temp3pm           21266 non-null  float64
#  21  RainToday         20907 non-null  object
#  22  RainTomorrow      20907 non-null  object
#  23  RainfallTomorrow  20907 non-null  float64
# dtypes: float64(17), object(7)
# memory usage: 4.0+ MB

# %%
df_train['season'] = df_train['Date'].apply(asignar_estacion)

# %%
df_test = preprocesamiento(df_test)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5415 entries, 21657 to 27071
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              5415 non-null   object
#  1   Location          5415 non-null   object
#  2   MinTemp           5227 non-null   float64
#  3   MaxTemp           5226 non-null   float64
#  4   Rainfall          5197 non-null   float64
#  5   Evaporation       3129 non-null   float64
#  6   Sunshine          2740 non-null   float64
#  7   WindGustDir       5343 non-null   object
#  8   WindGustSpeed     5343 non-null   float64
#  9   WindDir9am        5188 non-null   object
#  10  WindDir3pm        5392 non-null   object
#  11  WindSpeed9am      5407 non-null   float64
#  12  WindSpeed3pm      5411 non-null   float64
#  13  Humidity9am       5105 non-null   float64
#  14  Humidity3pm       5111 non-null   float64
#  15  Pressure9am       5226 non-null   float64
#  16  Pressure3pm       5229 non-null   float64
#  17  Cloud9am          3316 non-null   float64
#  18  Cloud3pm          3419 non-null   float64
#  19  Temp9am           5227 non-null   float64
#  20  Temp3pm           5230 non-null   float64
#  21  RainToday         5197 non-null   object
#  22  RainTomorrow      5198 non-null   object
#  23  RainfallTomorrow  5198 non-null   float64
# dtypes: float64(17), object(7)
# memory usage: 1015.4+ KB

# %%
df_test['season'] = df_test['Date'].apply(asignar_estacion)

# %%
df_test
# Out:
#             Date          Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 21657 2015-11-01          Adelaide     15.5     25.2       0.4         7.12
# 21658 2015-11-01  MelbourneAirport     15.0     27.0       4.8         7.00
# 21659 2015-11-01             Cobar     16.7     30.2       2.4         7.20
# 21660 2015-11-01      MountGambier     12.0     18.3       0.0         6.60
# 21661 2015-11-01            Sydney     17.5     26.8       0.0         7.80
# ...          ...               ...      ...      ...       ...          ...
# 27067 2017-06-24          Canberra      0.1     14.4       0.0         1.60
# 27068 2017-06-24          Dartmoor      6.2     11.8       3.0         1.60
# 27069 2017-06-24             Cobar      8.3     16.2       0.0         1.60
# 27070 2017-06-24          Adelaide      5.0     17.3       0.0         1.60
# 27071 2017-06-24      MountGambier      4.8     12.3       2.2         1.60
#
#        Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Pressure9am  \
# 21657      5.30         WSW           28.0          N  ...      1010.3
# 21658      5.20           N           72.0          N  ...      1008.3
# 21659      5.30           W           65.0         NE  ...      1012.9
# 21660      1.80         WNW           37.0        WNW  ...      1010.7
# 21661      9.00          NE           44.0          E  ...      1015.2
# ...         ...         ...            ...        ...  ...         ...
# 27067      7.45          NW           48.0          N  ...      1017.5
# 27068      7.45           W           20.0         NW  ...      1019.8
# 27069      7.45         WSW           20.0          W  ...      1020.2
# 27070      7.45           W           17.0          W  ...      1020.7
# 27071      7.45           W           28.0        NNW  ...      1020.0
#
#        Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 21657       1009.7      4.75      5.75     18.5     24.1         No
# 21658       1006.7      4.00      7.00     21.2     21.0        Yes
# 21659       1008.3      6.00      6.00     21.6     28.2        Yes
# 21660       1009.0      8.00      7.00     14.9     15.3         No
# 21661       1010.6      1.00      3.00     21.9     25.4         No
# ...            ...       ...       ...      ...      ...        ...
# 27067       1016.2      3.80      5.50      9.1     13.0         No
# 27068       1017.8      3.80      5.50      6.9     10.9        Yes
# 27069       1018.5      3.80      7.00     14.2     14.5         No
# 27070       1018.5      3.80      5.50      9.6     16.7         No
# 27071       1018.0      5.00      8.00      8.2     11.5        Yes
#
#        RainTomorrow  RainfallTomorrow  season
# 21657            No               0.0  Spring
# 21658            No               0.2  Spring
# 21659           Yes               7.6  Spring
# 21660           Yes               2.6  Spring
# 21661           Yes              26.0  Spring
# ...             ...               ...     ...
# 27067            No               0.0  Winter
# 27068            No               0.2  Winter
# 27069            No               0.0  Winter
# 27070            No               0.0  Winter
# 27071            No               0.6  Winter
#
# [5415 rows x 25 columns]

# %% [markdown]
# # Analisis exploratorio

# %%
summary = df_filtrado.describe()
print(summary)
# Out:
#                                 Date       MinTemp       MaxTemp  \
# count                          27072  27072.000000  27072.000000
# mean   2013-04-06 13:45:19.148936192     11.328903     21.987982
# min              2009-01-01 00:00:00     -8.000000      4.100000
# 25%              2011-01-22 18:00:00      7.400000     16.600000
# 50%              2013-05-12 12:00:00     11.000000     21.100000
# 75%              2015-06-03 06:00:00     15.200000     26.300000
# max              2017-06-24 00:00:00     33.900000     46.800000
# std                              NaN      5.705777      6.728221
#
#            Rainfall   Evaporation      Sunshine  WindGustSpeed  WindSpeed9am  \
# count  27072.000000  27072.000000  27072.000000   27072.000000  27072.000000
# mean       2.046205      4.862742      6.844573      41.874885     15.193268
# min        0.000000      0.000000      0.000000       9.000000      0.000000
# 25%        0.000000      2.200000      4.166667      31.000000      9.000000
# 50%        0.000000      4.000000      7.100000      39.000000     13.000000
# 75%        1.000000      6.600000      9.700000      50.000000     20.000000
# max      119.400000     86.200000     14.300000     122.000000     69.000000
# std        6.302651      3.622090      3.615105      14.050626      9.429529
#
#        WindSpeed3pm   Humidity9am   Humidity3pm   Pressure9am   Pressure3pm  \
# count  27072.000000  27072.000000  27072.000000  27072.000000  27072.000000
# mean      20.068882     68.794094     50.561941   1018.260506   1016.173059
# min        0.000000      5.000000      1.000000    982.300000    984.900000
# 25%       13.000000     57.000000     37.000000   1013.300000   1011.300000
# 50%       19.000000     70.000000     50.000000   1018.400000   1016.300000
# 75%       26.000000     83.000000     63.000000   1023.300000   1021.100000
# max       76.000000    100.000000    100.000000   1040.600000   1037.900000
# std        8.954737     18.615222     19.798477      7.381048      7.229245
#
#            Cloud9am      Cloud3pm       Temp9am       Temp3pm  \
# count  27072.000000  27072.000000  27072.000000  27072.000000
# mean       4.658544      4.702662     15.553477     20.485509
# min        0.000000      0.000000     -1.300000      3.700000
# 25%        2.800000      3.000000     11.400000     15.400000
# 50%        5.000000      5.000000     15.000000     19.600000
# 75%        7.000000      7.000000     19.300000     24.700000
# max        9.000000      8.000000     38.600000     46.100000
# std        2.462978      2.312414      5.710087      6.562406
#
#        RainfallTomorrow
# count      27072.000000
# mean           2.046201
# min            0.000000
# 25%            0.000000
# 50%            0.000000
# 75%            1.000000
# max          119.400000
# std            6.302651

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(8, 5))
plt.xticks(rotation=75, fontsize=12)
sns.boxplot(x='Location', y='Rainfall', data=df_filtrado)
plt.title('')
plt.xlabel('ciudades')
plt.ylabel('cantidad en mm')
plt.show()

# %% [markdown]
# La lluvia depende de tres factores: la presion atmosferica, la temperatura y la humedad.
# Vamos a estudiar estas tres variables.

# %%
df_filtrado.boxplot(column=['Pressure9am','Pressure3pm'])
plt.title('Variaciones de presion, humedad y temperatura a las 9AM y 3PM')
plt.show()

# %%
df_filtrado.boxplot(column=['Humidity9am','Humidity3pm'])
plt.title('Variacion de la Humedad')
plt.show()

# %%
df_filtrado.boxplot(column=['Temp9am','Temp3pm'])
plt.title('Variacion de la Temperatura en grados')
plt.show()

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(8, 5))
plt.xticks(rotation=75, fontsize=12)
sns.boxplot(x='Location', y='Pressure9am', data=df_filtrado)
plt.title('Presiones registradas a las 9am')
plt.xlabel('ciudades')
plt.ylabel('cantidad en mm')
plt.show()

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(8, 5))
plt.xticks(rotation=75, fontsize=12)
sns.boxplot(x='Location', y='Pressure3pm', data=df_filtrado)
plt.title('Presiones registradas a las 3pm')
plt.xlabel('ciudades')
plt.ylabel('cantidad en mm')
plt.show()

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(8, 5))
plt.xticks(rotation=75, fontsize=12)
sns.boxplot(x='Location', y= 'Humidity9am', data=df_filtrado)
plt.title('Humedad registrada a las 9 AM' )
plt.xlabel('ciudades')
plt.ylabel('porcenaje')
plt.show()

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(8, 5))
plt.xticks(rotation=75, fontsize=12)
sns.boxplot(x='Location', y='Humidity3pm', data=df_filtrado)
plt.title('Humedad registrada a las 3 PM')
plt.xlabel('ciudades')
plt.ylabel('porcentaje')
plt.show()

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(8, 5))
plt.xticks(rotation=75, fontsize=12)
sns.boxplot(x='Location', y= 'Temp9am', data=df_filtrado)
plt.title('Temperatura registrada a las 9 AM' )
plt.xlabel('ciudades')
plt.ylabel('porcenaje')
plt.show()

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(8, 5))
plt.xticks(rotation=75, fontsize=12)
sns.boxplot(x='Location', y= 'Temp3pm', data=df_filtrado)
plt.title('Temperatura registrada a las 3 PM' )
plt.xlabel('ciudades')
plt.ylabel('porcenaje')
plt.show()

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(8, 8))
plt.xticks(rotation=75, fontsize=12)
sns.boxplot(x='Location', y= 'MinTemp', data=df_filtrado)
plt.title('Temperaturas minimas registradas')
plt.xlabel('ciudades')
plt.ylabel('grados')
plt.show()

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(8, 8))
plt.xticks(rotation=75, fontsize=12)
sns.boxplot(x='Location', y= 'MaxTemp', data=df_filtrado)
plt.title('Temperaturas maximas registradas')
plt.xlabel('ciudades')
plt.ylabel('grados')
plt.show()

# %% [markdown]
# Decidimos mantener los outliers ya que consderamos que pueden ser casos atipicos puesto que al disciminarlos por ciudad estan presentes en la mayoria.

# %%
plt.figure(figsize=(16, 16))

for idx, col in enumerate(df_filtrado.columns[2:7], start=1):
    plt.subplot(4, 4, idx)
    plt.scatter(data=df_filtrado, x=col, y='RainfallTomorrow', alpha=.3)
    plt.title(col)

# %%
plt.figure(figsize=(16, 16))

for idx, col in enumerate(df_filtrado.columns[11:22], start=1):
    plt.subplot(4, 4, idx)
    plt.scatter(data=df_filtrado, x=col, y='RainfallTomorrow', alpha=.3)
    plt.title(col)

# %% [markdown]
# ## Matriz de correlacion

# %%
corr = df_filtrado.drop('WindGustDir', axis=1)\
           .drop('Date', axis = 1)\
           .drop('Location', axis = 1)\
           .drop('WindDir9am', axis = 1)\
           .drop('WindDir3pm', axis = 1)\
           .drop('RainToday', axis = 1)\
           .drop('RainTomorrow', axis = 1)\
           .drop('season', axis = 1)\
           .corr().round(2)

plt.figure(figsize = (13,13   ))
sns.heatmap(corr, annot=True)
plt.show()

# %% [markdown]
# ## Codificacion de variables categoricas

# %%
df_train['WindGustDir'].unique()
# Out:
# array(['SW', 'S', 'SSW', 'W', 'SSE', 'E', 'SE', 'NE', 'NNE', 'WSW', 'WNW',
#        'NW', 'N', 'ESE', 'ENE', 'NNW'], dtype=object)

# %%
df_train_codificado = codificar_variables(df_train)

# %%
df_train_codificado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21657 entries, 0 to 21656
# Data columns (total 79 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Date                       21657 non-null  datetime64[ns]
#  1   MinTemp                    21657 non-null  float64
#  2   MaxTemp                    21657 non-null  float64
#  3   Rainfall                   21657 non-null  float64
#  4   Evaporation                21657 non-null  float64
#  5   Sunshine                   21657 non-null  float64
#  6   WindGustDir                21657 non-null  object
#  7   WindGustSpeed              21657 non-null  float64
#  8   WindDir9am                 21657 non-null  object
#  9   WindDir3pm                 21657 non-null  object
#  10  WindSpeed9am               21657 non-null  float64
#  11  WindSpeed3pm               21657 non-null  float64
#  12  Humidity9am                21657 non-null  float64
#  13  Humidity3pm                21657 non-null  float64
#  14  Pressure9am                21657 non-null  float64
#  15  Pressure3pm                21657 non-null  float64
#  16  Cloud9am                   21657 non-null  float64
#  17  Cloud3pm                   21657 non-null  float64
#  18  Temp9am                    21657 non-null  float64
#  19  Temp3pm                    21657 non-null  float64
#  20  RainfallTomorrow           21657 non-null  float64
#  21  WindGustDir_SW             21657 non-null  int64
#  22  WindDir9am_SW              21657 non-null  int64
#  23  WindDir3pm_SW              21657 non-null  int64
#  24  WindGustDir_S              21657 non-null  int64
#  25  WindDir9am_S               21657 non-null  int64
#  26  WindDir3pm_S               21657 non-null  int64
#  27  WindGustDir_SSW            21657 non-null  int64
#  28  WindDir9am_SSW             21657 non-null  int64
#  29  WindDir3pm_SSW             21657 non-null  int64
#  30  WindGustDir_W              21657 non-null  int64
#  31  WindDir9am_W               21657 non-null  int64
#  32  WindDir3pm_W               21657 non-null  int64
#  33  WindGustDir_SSE            21657 non-null  int64
#  34  WindDir9am_SSE             21657 non-null  int64
#  35  WindDir3pm_SSE             21657 non-null  int64
#  36  WindGustDir_E              21657 non-null  int64
#  37  WindDir9am_E               21657 non-null  int64
#  38  WindDir3pm_E               21657 non-null  int64
#  39  WindGustDir_SE             21657 non-null  int64
#  40  WindDir9am_SE              21657 non-null  int64
#  41  WindDir3pm_SE              21657 non-null  int64
#  42  WindGustDir_NE             21657 non-null  int64
#  43  WindDir9am_NE              21657 non-null  int64
#  44  WindDir3pm_NE              21657 non-null  int64
#  45  WindGustDir_NNE            21657 non-null  int64
#  46  WindDir9am_NNE             21657 non-null  int64
#  47  WindDir3pm_NNE             21657 non-null  int64
#  48  WindGustDir_WSW            21657 non-null  int64
#  49  WindDir9am_WSW             21657 non-null  int64
#  50  WindDir3pm_WSW             21657 non-null  int64
#  51  WindGustDir_WNW            21657 non-null  int64
#  52  WindDir9am_WNW             21657 non-null  int64
#  53  WindDir3pm_WNW             21657 non-null  int64
#  54  WindGustDir_NW             21657 non-null  int64
#  55  WindDir9am_NW              21657 non-null  int64
#  56  WindDir3pm_NW              21657 non-null  int64
#  57  WindGustDir_N              21657 non-null  int64
#  58  WindDir9am_N               21657 non-null  int64
#  59  WindDir3pm_N               21657 non-null  int64
#  60  WindGustDir_ESE            21657 non-null  int64
#  61  WindDir9am_ESE             21657 non-null  int64
#  62  WindDir3pm_ESE             21657 non-null  int64
#  63  WindGustDir_ENE            21657 non-null  int64
#  64  WindDir9am_ENE             21657 non-null  int64
#  65  WindDir3pm_ENE             21657 non-null  int64
#  66  RainToday_Yes              21657 non-null  bool
#  67  RainTomorrow_Yes           21657 non-null  bool
#  68  season_Spring              21657 non-null  bool
#  69  season_Summer              21657 non-null  bool
#  70  season_Winter              21657 non-null  bool
#  71  Location_Canberra          21657 non-null  bool
#  72  Location_Cobar             21657 non-null  bool
#  73  Location_Dartmoor          21657 non-null  bool
#  74  Location_Melbourne         21657 non-null  bool
#  75  Location_MelbourneAirport  21657 non-null  bool
#  76  Location_MountGambier      21657 non-null  bool
#  77  Location_Sydney            21657 non-null  bool
#  78  Location_SydneyAirport     21657 non-null  bool
# dtypes: bool(13), datetime64[ns](1), float64(17), int64(45), object(3)
# memory usage: 11.2+ MB

# %%
df_test_codificado = codificar_variables(df_test)

# %%
df_test_codificado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5415 entries, 21657 to 27071
# Data columns (total 79 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Date                       5415 non-null   datetime64[ns]
#  1   MinTemp                    5415 non-null   float64
#  2   MaxTemp                    5415 non-null   float64
#  3   Rainfall                   5415 non-null   float64
#  4   Evaporation                5415 non-null   float64
#  5   Sunshine                   5415 non-null   float64
#  6   WindGustDir                5415 non-null   object
#  7   WindGustSpeed              5415 non-null   float64
#  8   WindDir9am                 5415 non-null   object
#  9   WindDir3pm                 5415 non-null   object
#  10  WindSpeed9am               5415 non-null   float64
#  11  WindSpeed3pm               5415 non-null   float64
#  12  Humidity9am                5415 non-null   float64
#  13  Humidity3pm                5415 non-null   float64
#  14  Pressure9am                5415 non-null   float64
#  15  Pressure3pm                5415 non-null   float64
#  16  Cloud9am                   5415 non-null   float64
#  17  Cloud3pm                   5415 non-null   float64
#  18  Temp9am                    5415 non-null   float64
#  19  Temp3pm                    5415 non-null   float64
#  20  RainfallTomorrow           5415 non-null   float64
#  21  WindGustDir_SW             5415 non-null   int64
#  22  WindDir9am_SW              5415 non-null   int64
#  23  WindDir3pm_SW              5415 non-null   int64
#  24  WindGustDir_S              5415 non-null   int64
#  25  WindDir9am_S               5415 non-null   int64
#  26  WindDir3pm_S               5415 non-null   int64
#  27  WindGustDir_SSW            5415 non-null   int64
#  28  WindDir9am_SSW             5415 non-null   int64
#  29  WindDir3pm_SSW             5415 non-null   int64
#  30  WindGustDir_W              5415 non-null   int64
#  31  WindDir9am_W               5415 non-null   int64
#  32  WindDir3pm_W               5415 non-null   int64
#  33  WindGustDir_SSE            5415 non-null   int64
#  34  WindDir9am_SSE             5415 non-null   int64
#  35  WindDir3pm_SSE             5415 non-null   int64
#  36  WindGustDir_E              5415 non-null   int64
#  37  WindDir9am_E               5415 non-null   int64
#  38  WindDir3pm_E               5415 non-null   int64
#  39  WindGustDir_SE             5415 non-null   int64
#  40  WindDir9am_SE              5415 non-null   int64
#  41  WindDir3pm_SE              5415 non-null   int64
#  42  WindGustDir_NE             5415 non-null   int64
#  43  WindDir9am_NE              5415 non-null   int64
#  44  WindDir3pm_NE              5415 non-null   int64
#  45  WindGustDir_NNE            5415 non-null   int64
#  46  WindDir9am_NNE             5415 non-null   int64
#  47  WindDir3pm_NNE             5415 non-null   int64
#  48  WindGustDir_WSW            5415 non-null   int64
#  49  WindDir9am_WSW             5415 non-null   int64
#  50  WindDir3pm_WSW             5415 non-null   int64
#  51  WindGustDir_WNW            5415 non-null   int64
#  52  WindDir9am_WNW             5415 non-null   int64
#  53  WindDir3pm_WNW             5415 non-null   int64
#  54  WindGustDir_NW             5415 non-null   int64
#  55  WindDir9am_NW              5415 non-null   int64
#  56  WindDir3pm_NW              5415 non-null   int64
#  57  WindGustDir_N              5415 non-null   int64
#  58  WindDir9am_N               5415 non-null   int64
#  59  WindDir3pm_N               5415 non-null   int64
#  60  WindGustDir_ESE            5415 non-null   int64
#  61  WindDir9am_ESE             5415 non-null   int64
#  62  WindDir3pm_ESE             5415 non-null   int64
#  63  WindGustDir_ENE            5415 non-null   int64
#  64  WindDir9am_ENE             5415 non-null   int64
#  65  WindDir3pm_ENE             5415 non-null   int64
#  66  RainToday_Yes              5415 non-null   bool
#  67  RainTomorrow_Yes           5415 non-null   bool
#  68  season_Spring              5415 non-null   bool
#  69  season_Summer              5415 non-null   bool
#  70  season_Winter              5415 non-null   bool
#  71  Location_Canberra          5415 non-null   bool
#  72  Location_Cobar             5415 non-null   bool
#  73  Location_Dartmoor          5415 non-null   bool
#  74  Location_Melbourne         5415 non-null   bool
#  75  Location_MelbourneAirport  5415 non-null   bool
#  76  Location_MountGambier      5415 non-null   bool
#  77  Location_Sydney            5415 non-null   bool
#  78  Location_SydneyAirport     5415 non-null   bool
# dtypes: bool(13), datetime64[ns](1), float64(17), int64(45), object(3)
# memory usage: 2.8+ MB

# %%
df_train_codificado = df_train_codificado.drop(columns= ['Date', 'WindGustDir', 'WindDir9am', 'WindDir3pm'])

# %%
df_test_codificado = df_test_codificado.drop(columns= ['Date', 'WindGustDir', 'WindDir9am', 'WindDir3pm'])

# %% [markdown]
# ## Estandarizacion

# %% [markdown]
# No nos funciona la estandarizacion

# %%
#df_train_estandarizado = estandarizar(df_train)

# %%
#df_train_estandarizado.info()

# %%
#df_test = estandarizar(df_test)

# %%
#df_test_estandarizado.info()

# %% [markdown]
# **VALIDACION TRAIN-TEST**

# %%
# Dividir el conjunto de datos de entrenamiento en características (X) y variables objetivo (y)
X_train_regresion = df_train_codificado.drop(columns=['RainfallTomorrow'])
X_train_clasificacion = df_train_codificado.drop(columns=['RainTomorrow_Yes'])

y_train_rainfall_tomorrow = df_train_codificado['RainfallTomorrow']
y_train_rain_tomorrow = df_train_codificado['RainTomorrow_Yes']

# %%
# Dividir el conjunto de datos de test en características (X) y variables objetivo (y)
X_test_regresion = df_test_codificado.drop(columns=['RainfallTomorrow'])
X_test_clasificacion = df_test_codificado.drop(columns=['RainTomorrow_Yes'])

y_test_rain_tomorrow = df_test_codificado['RainTomorrow_Yes']
y_test_rainfall_tomorrow = df_test_codificado['RainfallTomorrow']

# %% [markdown]
# ## Regresion Lineal

# %%
def metricas(y_test, y_pred):
    print('R2:   %.2f' % r2_score(y_test, y_pred))
    print('MSE:  %.2f' % mean_squared_error(y_test, y_pred))
    print('MAE:  %.2f' % mean_absolute_error(y_test, y_pred))
    print('MAPE: %.2f' % mean_absolute_percentage_error(y_test, y_pred))

# %%
def mini_batch_gradient_descent(X_train, y_train, X_test, y_test, lr=0.01, epochs=100, batch_size=11):
    n = X_train.shape[0]
    m = X_train.shape[1]

    X_train = np.hstack((np.ones((n, 1)), X_train))
    X_test = np.hstack((np.ones((X_test.shape[0], 1)), X_test))

    W = np.random.randn(m + 1).reshape(-1, 1)

    train_errors = []
    test_errors = []

    for i in range(epochs):

        # Permutación aleatoria de los datos
        permutation = np.random.permutation(n)
        X_train = X_train[permutation]
        y_train = y_train[permutation]


        for j in range(0, n, batch_size):
            # Obtener un lote (mini-batch) de datos
            x_batch = X_train[j:j+batch_size, :]
            y_batch = y_train[j:j+batch_size].reshape(-1, 1)

            prediction = np.matmul(x_batch, W)
            error = y_batch - prediction
            #train_mse = np.mean(error ** 2)
            #train_errors.append(train_mse)

            gradient = -2 * np.matmul(x_batch.T, error) / batch_size

            W = W - (lr * gradient)

            prediction_test = np.matmul(X_test, W)
            error_test = y_test - prediction_test
            #test_mse = np.mean(error_test ** 2)
            #test_errors.append(test_mse)

    plt.figure(figsize=(12, 6))
    plt.plot(train_errors, label='Error de entrenamiento')
    plt.plot(test_errors, label='Error de prueba')
    plt.xlabel('Iteración')
    plt.ylabel('Error cuadrático medio')
    plt.legend()
    plt.title('Error de entrenamiento y prueba vs iteraciones (Mini-Batch GD)')
    plt.show()

    return W

# %%
regresion = LinearRegression()
regresion.fit(X_train_regresion, y_train_rainfall_tomorrow)
# Out:
# LinearRegression()

# %%
y_pred_regresion = regresion.predict(X_test_regresion)

metricas(y_test_rainfall_tomorrow, y_pred_regresion)
# Out:
# R2:   0.38
# MSE:  28.10
# MAE:  2.26
# MAPE: 2296498139488833.50

# %% [markdown]
#  R2 nos da 0.38, es decir que solo pueden llegar a explicar un 38% de la variabilidad de los datos.
#
#  MSE es similar a la medida estadística de varianza que nos permite medir la incertidumbre alrededor de nuestro más probable pronóstico.En nuestro caso es de 28.10, por lo tanto la incertidumbre en el resultado es de 28,1 mm.
#
#  El error absoluto medio(MAE) es una medida común del error de pronóstico en análisis de series de tiempo, nos da 2,26.

# %% [markdown]
# ### Gradiente Descendiente (Mini_batch)

# %%
y_train_gd = y_train_rainfall_tomorrow.values.reshape(-1, 1)
y_test_gd = y_test_rainfall_tomorrow.values.reshape(-1, 1)

# %%
mini_batch_gradient_descent(X_train_regresion, y_train_gd,\
                            X_test_regresion, y_test_gd,\
                            epochs=2)
#Cortamos la ejecucion pq no terminaba, suponemos que al no tener datos estandarizados no llega al resultado
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-76-868f4d53dac3> in <cell line: 1>()
# ----> 1 mini_batch_gradient_descent(X_train_regresion, y_train_gd,\
#       2                             X_test_regresion, y_test_gd,\
#       3                             epochs=2)
#       4 #Cortamos la ejecucion pq no terminaba
#
# <ipython-input-59-8c2cbc1ba353> in mini_batch_gradient_descent(X_train, y_train, X_test, y_test, lr, epochs, batch_size)
#      33             W = W - (lr * gradient)
#      34
# ---> 35             prediction_test = np.matmul(X_test, W)
#      36             error_test = y_test - prediction_test
#      37             #test_mse = np.mean(error_test ** 2)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Metodos de regularizacion

# %% [markdown]
# ## Ridge

# %%
ridge = RidgeCV()
ridge.fit(X_train_regresion, y_train_rainfall_tomorrow)
# Out:
# RidgeCV()

# %%
y_pred_ridge = ridge.predict(X_test_regresion)

metricas(y_test_rainfall_tomorrow, y_pred_ridge)
# Out:
# R2:   0.38
# MSE:  28.11
# MAE:  2.26
# MAPE: 2292119590602723.50

# %%
print("\nCoeficientes del modelo Ridge:")
print(ridge.coef_)
# Out:
# Coeficientes del modelo Ridge:
# [-5.33263438e-02  9.67982109e-02  1.24007921e-01 -1.09616918e-02
#  -1.02007801e-01  4.48578355e-02  9.56568125e-03 -3.02230596e-02
#  -8.57342440e-03  6.03969075e-02  2.65667937e-01 -2.81718161e-01
#  -2.90442765e-02  1.04475749e-02  8.05064173e-03 -1.16553286e-02
#  -1.01063246e-01  1.71414260e-01  3.09653633e-01  2.70031372e-01
#   5.00589779e-01  2.58738935e-02  3.48465929e-02  4.49339441e-01
#   3.33760550e-01 -2.77774725e-01  2.57306909e-01  2.64105648e-01
#   6.34105317e-01  7.42946428e-01  4.14386625e-02  8.68479860e-01
#   9.74830719e-01 -6.84876109e-01  8.40519948e-01  5.80191748e-01
#  -4.31560144e-02 -3.75873482e-02  5.51942629e-01 -5.16476891e-01
#  -1.57864823e-01  3.63277865e-01 -9.63928037e-02  1.05605330e-01
#   3.51204465e-01  7.35426072e-02 -1.48758247e-01  2.66690355e-03
#  -2.82780933e-02  5.04165708e-02 -6.56573515e-02 -2.29207290e-01
#   7.37927333e-02  6.28022780e-02 -2.13967887e-01  5.87728802e-01
#   8.71790157e-01 -1.05338577e-01  1.30874947e-01  5.61684249e-01
#  -1.99188615e-01 -2.67675457e-01  6.35043790e+00 -1.54318815e-01
#   1.02025406e-01 -2.42101024e-01  2.01786201e-01  1.92847577e-01
#  -7.67359098e-01 -3.66964617e-02 -5.00219928e-01 -6.36899613e-01
#   7.48739496e-01  4.64935532e-01]

# %%
print("Ridge_Score df_train:", ridge.score(X_train_regresion, y_train_rainfall_tomorrow))
print("Ridge_Score df_test:", ridge.score(X_test_regresion, y_test_rainfall_tomorrow))
# Out:
# Ridge_Score df_train: 0.3526448783812667
# Ridge_Score df_test: 0.37733590544185014

# %% [markdown]
# ## Lasso

# %%
lasso = LassoCV()
lasso.fit(X_train_regresion, y_train_rainfall_tomorrow)
# Out:
# LassoCV()

# %%
y_pred_lasso = lasso.predict(X_test_regresion)

metricas(y_test_rainfall_tomorrow, y_pred_lasso)
# Out:
# R2:   0.37
# MSE:  28.48
# MAE:  2.15
# MAPE: 1916978861509673.75

# %%
print("\nCoeficientes del modelo Lasso:")
print(lasso.coef_)
# Out:
# Coeficientes del modelo Lasso:
# [-0.00000000e+00  8.03321666e-02  1.29089498e-01  5.89513855e-03
#  -9.77818211e-02  4.09686316e-02  3.63038342e-03 -3.39771223e-02
#  -1.40202754e-02  5.88880718e-02  2.55017845e-01 -2.55408981e-01
#  -8.91513225e-03  0.00000000e+00  0.00000000e+00  0.00000000e+00
#  -0.00000000e+00 -0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#   5.55206826e-03  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00 -0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -0.00000000e+00 -2.13749421e-01 -0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00 -0.00000000e+00  6.05145978e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00  8.60998180e-02  0.00000000e+00
#  -1.15595501e-01  0.00000000e+00 -0.00000000e+00 -2.40537478e-02
#   1.06852575e-01  0.00000000e+00]

# %%
print("Lasso_Score df_train:", lasso.score(X_train_regresion, y_train_rainfall_tomorrow))
print("Lasso_Score df_test:", lasso.score(X_test_regresion, y_test_rainfall_tomorrow))
# Out:
# Lasso_Score df_train: 0.342968263212857
# Lasso_Score df_test: 0.36900458642726464

# %% [markdown]
# ### ElasticNet

# %%
elastic = ElasticNetCV()
elastic.fit(X_train_regresion, y_train_rainfall_tomorrow)
# Out:
# ElasticNetCV()

# %%
y_pred_elastic = elastic.predict(X_test_regresion)

metricas(y_test_rainfall_tomorrow, y_pred_elastic)
# Out:
# R2:   0.36
# MSE:  29.03
# MAE:  2.23
# MAPE: 2354160188408417.50

# %%
print("\nCoeficientes del modelo ElasticNet:")
print(elastic.coef_)
# Out:
# Coeficientes del modelo ElasticNet:
# [-8.23090086e-04  8.14646775e-02  1.38808706e-01  5.46469696e-03
#  -1.28694521e-01  5.19767897e-02  1.74656352e-03 -4.07167144e-02
#  -1.49781985e-02  7.06729407e-02  2.72028885e-01 -2.88572844e-01
#  -1.70487597e-02  6.51223227e-03  0.00000000e+00  0.00000000e+00
#  -0.00000000e+00 -0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00 -0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00 -0.00000000e+00  0.00000000e+00 -0.00000000e+00
#  -0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -0.00000000e+00 -1.61516900e-01 -0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00 -0.00000000e+00  4.54167062e+00 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00  3.76505410e-02  0.00000000e+00
#  -9.26782063e-02 -0.00000000e+00 -5.66599740e-02 -0.00000000e+00
#   5.45153595e-02  0.00000000e+00]

# %%
print("ElasticNet_Score df_train:", elastic.score(X_train_regresion, y_train_rainfall_tomorrow))
print("ElasticNet_Score df_test:", elastic.score(X_test_regresion, y_test_rainfall_tomorrow))
# Out:
# ElasticNet_Score df_train: 0.33270260297492915
# ElasticNet_Score df_test: 0.35682597443766284

# %% [markdown]
# De los cuatro modelos lineales que probamos vemos que la regresion lineal y Ridge nos dan un R2 de aproximadamente 0.38, es decir que solo pueden llegar a explicar un 38% de la variabilidad de los datos.

# %% [markdown]
# En todos los casos el score de test nos da levemente mejor que el de train,podemos asegurar que no esta sobrejustado.
